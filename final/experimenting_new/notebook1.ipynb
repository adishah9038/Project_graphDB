# %%
from inject_relationship import execute_ultra_optimized_relationships
from inject_node import execute_ultra_optimized_nodes
from schema import schema_modelling
from sqlite_to_csv import export_sqlite_to_csv
from erd_text import erd_text_generate

# %%
# ENV
from dotenv import load_dotenv
load_dotenv()
#LLM
from langchain_google_genai import ChatGoogleGenerativeAI
from google.generativeai.types import HarmCategory, HarmBlockThreshold

import os

os.environ["GOOGLE_API_KEY"] = os.environ["GOOGLE_API_KEY0"]
llm1 = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.5,
    max_tokens=None,
    timeout=None,
    max_retries=1,
    safety_settings={
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
    }
)

os.environ["GOOGLE_API_KEY"] = os.environ["GOOGLE_API_KEY2"]
llm2 = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.2,
    max_tokens=None,
    timeout=None,
    max_retries=1,
)

os.environ["GOOGLE_API_KEY"] = os.environ["GOOGLE_API_KEY3"]
llm3 = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.2,
    max_tokens=None,
    timeout=None,
    max_retries=1,
)

# %%
from neo4j import GraphDatabase

NEO4J_URI="neo4j+s://eaee53dc.databases.neo4j.io"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="DH_4xGGIxkB2Acm6lfRoU6FOdYbW2bcGga2b4yLoIQE"
NEO4J_DATABASE="neo4j"
AURA_INSTANCEID="eaee53dc"
AURA_INSTANCENAME="Free instance"

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
print(driver)
# Out:
# <neo4j._sync.driver.Neo4jDriver object at 0x000001CD288A97D0>

# %%
from langchain_neo4j import Neo4jGraph
enhanced_graph = Neo4jGraph(
    url=NEO4J_URI,
    username="neo4j",
    password=NEO4J_PASSWORD,
    driver_config={
        "max_connection_lifetime": 300,  # 5 minutes
        "keep_alive": True,
        "max_connection_pool_size": 50
    },
    enhanced_schema=True)

# %%
db_name = "sales_master"
db_path = db_name+".sqlite"

# %%
replacements = export_sqlite_to_csv(db_name+".sqlite",db_name+"_files")
# Out:
# Processing table: customer_table
# Saved customer_table -> sales_master_files\customer_table.csv
# Processing table: order_table
# Saved order_table -> sales_master_files\order_table.csv
# Processing table: product_table
# Saved product_table -> sales_master_files\product_table.csv
# Processing table: order_product_table
# Saved order_product_table -> sales_master_files\order_product_table.csv
# All tables exported!

# %%
schema_info, erd_text = erd_text_generate(db_name, replacements)
print(erd_text)
# Out:
# Table: customer_table
# Columns:
#   - CUSTOMERNAME (TEXT)
#   - PHONE (TEXT)
#   - ADDRESSLINE1 (TEXT)
#   - ADDRESSLINE2 (TEXT)
#   - CITY (TEXT)
#   - STATE (TEXT)
#   - POSTALCODE (TEXT)
#   - COUNTRY (TEXT)
#   - TERRITORY (TEXT)
#   - CONTACTLASTNAME (TEXT)
#   - CONTACTFIRSTNAME (TEXT)
# Primary Key: CUSTOMERNAME
#
# Table: order_table
# Columns:
#   - ORDERNUMBER (INTEGER)
#   - ORDERDATE (TEXT)
#   - STATUS (TEXT)
#   - QTR_ID (INTEGER)
#   - MONTH_ID (INTEGER)
#   - YEAR_ID (INTEGER)
#   - CUSTOMERNAME (TEXT)
# Primary Key: ORDERNUMBER
# Foreign Keys:
#   - CUSTOMERNAME → customer_table.CUSTOMERNAME
#
# Table: product_table
# Columns:
#   - PRODUCTCODE (TEXT)
#   - MSRP (REAL)
#   - PRODUCTLINE (TEXT)
# Primary Key: PRODUCTCODE
#
# Table: order_product_table
# Columns:
#   - ORDERNUMBER (INTEGER)
#   - PRODUCTCODE (TEXT)
#   - QUANTITYORDERED (INTEGER)
#   - PRICEEACH (REAL)
#   - SALES (REAL)
#   - ORDERLINENUMBER (INTEGER)
#   - DEALSIZE (TEXT)
# Foreign Keys:
#   - PRODUCTCODE → product_table.PRODUCTCODE
#   - ORDERNUMBER → order_table.ORDERNUMBER

# %%
modelling_output = schema_modelling(erd_text,llm1)
print(modelling_output)
# Out:
# nodes=[Node(name='Customer', key='CUSTOMERNAME', properties=['PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME'], table_name=['customer_table']), Node(name='Order', key='ORDERNUMBER', properties=['ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID'], table_name=['order_table']), Node(name='Product', key='PRODUCTCODE', properties=['MSRP', 'PRODUCTLINE'], table_name=['product_table'])] relationships=[Relationship(source='Customer', target='Order', label='PLACED', key_s='CUSTOMERNAME', key_t='ORDERNUMBER', properties=[], table_name='order_table'), Relationship(source='Order', target='Product', label='CONTAINS', key_s='ORDERNUMBER', key_t='PRODUCTCODE', properties=['QUANTITYORDERED', 'PRICEEACH', 'SALES', 'ORDERLINENUMBER', 'DEALSIZE'], table_name='order_product_table')]

# %%
inject_node_stats = execute_ultra_optimized_nodes(modelling_output.nodes,driver,db_name+"_files")
# Out:
# 2025-09-19 11:26:13,996 - INFO - 🚀 Starting ULTRA-OPTIMIZED node injection for 3 node types
# 2025-09-19 11:26:15,158 - INFO - Node injection system initialized with 6 workers
# 2025-09-19 11:26:15,165 - INFO - Processing Customer nodes with ultra-optimized strategy
# 2025-09-19 11:26:15,165 - INFO - Processing Order nodes with ultra-optimized strategy
# 2025-09-19 11:26:15,165 - INFO - Processing Product nodes with ultra-optimized strategy
# 2025-09-19 11:26:15,181 - INFO - Loaded 109 records from product_table
# 2025-09-19 11:26:15,196 - INFO - Chunking Product: 109 records, complexity=1.3, batch_size=1600
# 2025-09-19 11:26:15,198 - INFO - Created 1 optimized chunks for Product
# 2025-09-19 11:26:15,198 - INFO - Loaded 92 records from customer_table
# 2025-09-19 11:26:15,211 - INFO - Loaded 307 records from order_table
# 2025-09-19 11:26:15,219 - INFO - Chunking Customer: 92 records, complexity=6.9, batch_size=500
# 2025-09-19 11:26:15,219 - INFO - Chunking Order: 307 records, complexity=1.6, batch_size=1000
# 2025-09-19 11:26:15,227 - INFO - Created 1 optimized chunks for Customer
# 2025-09-19 11:26:15,227 - INFO - Created 1 optimized chunks for Order
# 2025-09-19 11:26:15,402 - INFO - ✅ Product chunk 0: 109 processed in 0.20s (533 nodes/s)
# 2025-09-19 11:26:15,410 - INFO - 🎯 Product completed: 109 processed, 0 failed, 100.0% success, 472 nodes/s
# 2025-09-19 11:26:16,515 - INFO - ✅ Customer chunk 0: 92 processed in 1.28s (72 nodes/s)
# 2025-09-19 11:26:16,527 - INFO - 🎯 Customer completed: 92 processed, 0 failed, 100.0% success, 68 nodes/s
# 2025-09-19 11:26:16,964 - INFO - ✅ Order chunk 0: 307 processed in 1.73s (178 nodes/s)
# 2025-09-19 11:26:16,964 - INFO - 🎯 Order completed: 307 processed, 0 failed, 100.0% success, 171 nodes/s
# 2025-09-19 11:26:17,404 - INFO -
# 🎊 ULTRA-OPTIMIZED NODE INJECTION COMPLETE!
# 2025-09-19 11:26:17,412 - INFO - 📊 Performance Summary:
# 2025-09-19 11:26:17,414 - INFO -    • Node types: 3/3 successful
# 2025-09-19 11:26:17,414 - INFO -    • Records: 508 processed, 0 failed
# 2025-09-19 11:26:17,414 - INFO -    • Success rate: 100.0%
# 2025-09-19 11:26:17,414 - INFO -    • Duration: 3.41s
# 2025-09-19 11:26:17,414 - INFO -    • Throughput: 149 nodes/second

# %%
results = execute_ultra_optimized_relationships(
    relationships=modelling_output.relationships,
    driver=driver,
    output_dir=db_name+"_files",
    nodes_list=modelling_output.nodes,  # Pass your nodes list
    initial_batch_size=1000,  # Smaller for debugging
    max_workers=6  # Reduced for stability
)
# Out:
# 2025-09-17 19:43:18,608 - INFO - Starting ENHANCED injection for 9 relationships with retry mechanisms
# 2025-09-17 19:43:18,609 - INFO - Node lookup: {'Customer': 'customer_id', 'Staff': 'staff_id', 'Store': 'store_id', 'Order': 'order_id', 'Category': 'category_id', 'Brand': 'brand_id', 'Product': 'product_id'}
# 2025-09-17 19:43:18,814 - INFO - Neo4j connection test: Connection OK at 2025-09-17T14:13:18.816000000+00:00
# 2025-09-17 19:43:18,902 - INFO - Current database has 3410 nodes
# 2025-09-17 19:43:19,083 - INFO - Initialized with 3 workers, batch size 1000
# 2025-09-17 19:43:19,083 - INFO - === PRE-FLIGHT DATABASE CHECK ===
# 2025-09-17 19:43:19,179 - INFO - Database contains 3410 total nodes
# 2025-09-17 19:43:19,317 - INFO - Node counts by label:
# 2025-09-17 19:43:19,318 - INFO -   Order: 1615
# 2025-09-17 19:43:19,318 - INFO -   Customer: 1445
# 2025-09-17 19:43:19,319 - INFO -   Product: 321
# 2025-09-17 19:43:19,321 - INFO -   Staff: 10
# 2025-09-17 19:43:19,321 - INFO -   Brand: 9
# 2025-09-17 19:43:19,321 - INFO -   Category: 7
# 2025-09-17 19:43:19,321 - INFO -   Store: 3
# 2025-09-17 19:43:19,463 - INFO - Database contains 0 existing relationships:
# 2025-09-17 19:43:19,463 - INFO -
# Processing Relationship 1/9: MANAGES
# 2025-09-17 19:43:19,463 - INFO -    Source: Staff -> Target: Staff
# 2025-09-17 19:43:19,463 - INFO -    Keys: staff_id -> staff_id
# 2025-09-17 19:43:19,463 - INFO -    Table: staffs
# 2025-09-17 19:43:19,463 - INFO - Processing MANAGES with enhanced retry mechanisms
# 2025-09-17 19:43:19,644 - INFO - Node validation for MANAGES: Staff=10, Staff=10
# 2025-09-17 19:43:19,644 - INFO - Loaded 10 records from bike_files/staffs.csv
# 2025-09-17 19:43:19,644 - INFO - CSV columns: ['staff_id', 'first_name', 'last_name', 'email', 'phone', 'active', 'store_id', 'manager_id']
# 2025-09-17 19:43:19,662 - INFO - Preprocessed data: 10 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:43:19,662 - INFO - Sample data:
#    staff_id first_name last_name                       email           phone  active  store_id  manager_id
# 0         1    Fabiola   Jackson  fabiola.jackson@bikes.shop  (831) 555-5554       1         1         NaN
# 1         2     Mireya  Copeland  mireya.copeland@bikes.shop  (831) 555-5555       1         1         1.0
# 2         3      Genna   Serrano    genna.serrano@bikes.shop  (831) 555-5556       1         1         2.0
# 3         4     Virgie   Wiggins   virgie.wiggins@bikes.shop  (831) 555-5557       1         1         2.0
# 4         5   Jannette     David   jannette.david@bikes.shop  (516) 379-4444       1         2         1.0
# 2025-09-17 19:43:19,662 - INFO - Cypher mapping for MANAGES:
# 2025-09-17 19:43:19,662 - INFO -   CSV: staff_id -> staff_id
# 2025-09-17 19:43:19,662 - INFO -   Nodes: Staff.staff_id -> Staff.staff_id
# 2025-09-17 19:43:19,677 - INFO - Chunking MANAGES: 10 records, contention=LOW, batch_size=200
# 2025-09-17 19:43:19,678 - INFO - Created 1 chunks for MANAGES
# 2025-09-17 19:43:20,011 - INFO - Concurrent MANAGES chunk 0: 10 committed in 0.33s (30 records/s)
# 2025-09-17 19:43:20,114 - INFO - MANAGES completed: 10 committed (10 verified), 0 failed, 100.0% success, 15 records/s, avg retries: 0.0
# 2025-09-17 19:43:20,234 - INFO - MANAGES: 10 relationships created (10 verified)
# 2025-09-17 19:43:20,736 - INFO -
# Processing Relationship 2/9: WORKS_AT
# 2025-09-17 19:43:20,738 - INFO -    Source: Staff -> Target: Store
# 2025-09-17 19:43:20,738 - INFO -    Keys: staff_id -> store_id
# 2025-09-17 19:43:20,739 - INFO -    Table: staffs
# 2025-09-17 19:43:20,739 - INFO - Processing WORKS_AT with enhanced retry mechanisms
# 2025-09-17 19:43:20,946 - INFO - Node validation for WORKS_AT: Staff=10, Store=3
# 2025-09-17 19:43:20,946 - INFO - Loaded 10 records from bike_files/staffs.csv
# 2025-09-17 19:43:20,946 - INFO - CSV columns: ['staff_id', 'first_name', 'last_name', 'email', 'phone', 'active', 'store_id', 'manager_id']
# 2025-09-17 19:43:20,946 - INFO - Preprocessed data: 10 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:43:20,963 - INFO - Sample data:
#    staff_id first_name last_name                       email           phone  active  store_id  manager_id
# 0         1    Fabiola   Jackson  fabiola.jackson@bikes.shop  (831) 555-5554       1         1         NaN
# 1         2     Mireya  Copeland  mireya.copeland@bikes.shop  (831) 555-5555       1         1         1.0
# 2         3      Genna   Serrano    genna.serrano@bikes.shop  (831) 555-5556       1         1         2.0
# 3         4     Virgie   Wiggins   virgie.wiggins@bikes.shop  (831) 555-5557       1         1         2.0
# 4         5   Jannette     David   jannette.david@bikes.shop  (516) 379-4444       1         2         1.0
# 2025-09-17 19:43:20,963 - INFO - Cypher mapping for WORKS_AT:
# 2025-09-17 19:43:20,963 - INFO -   CSV: staff_id -> store_id
# 2025-09-17 19:43:20,963 - INFO -   Nodes: Staff.staff_id -> Store.store_id
# 2025-09-17 19:43:20,963 - INFO - Chunking WORKS_AT: 10 records, contention=LOW, batch_size=200
# 2025-09-17 19:43:20,970 - INFO - Created 1 chunks for WORKS_AT
# 2025-09-17 19:43:21,166 - INFO - Concurrent WORKS_AT chunk 0: 10 committed in 0.19s (51 records/s)
# 2025-09-17 19:43:21,270 - INFO - WORKS_AT completed: 10 committed (10 verified), 0 failed, 100.0% success, 19 records/s, avg retries: 0.0
# 2025-09-17 19:43:21,382 - INFO - WORKS_AT: 10 relationships created (10 verified)
# 2025-09-17 19:43:21,886 - INFO -
# Processing Relationship 3/9: PROCESSED_BY
# 2025-09-17 19:43:21,886 - INFO -    Source: Order -> Target: Staff
# 2025-09-17 19:43:21,886 - INFO -    Keys: order_id -> staff_id
# 2025-09-17 19:43:21,886 - INFO -    Table: orders
# 2025-09-17 19:43:21,889 - INFO - Processing PROCESSED_BY with enhanced retry mechanisms
# 2025-09-17 19:43:22,073 - INFO - Node validation for PROCESSED_BY: Order=1615, Staff=10
# 2025-09-17 19:43:22,077 - INFO - Loaded 1615 records from bike_files/orders.csv
# 2025-09-17 19:43:22,077 - INFO - CSV columns: ['order_id', 'customer_id', 'order_status', 'order_date', 'required_date', 'shipped_date', 'store_id', 'staff_id']
# 2025-09-17 19:43:22,078 - INFO - Preprocessed data: 1615 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:43:22,085 - INFO - Sample data:
#    order_id  customer_id  order_status  order_date required_date shipped_date  store_id  staff_id
# 0         1          259             4  2016-01-01    2016-01-03   2016-01-03         1         2
# 1         2         1212             4  2016-01-01    2016-01-04   2016-01-03         2         6
# 2         3          523             4  2016-01-02    2016-01-05   2016-01-03         2         7
# 3         4          175             4  2016-01-03    2016-01-04   2016-01-05         1         3
# 4         5         1324             4  2016-01-03    2016-01-06   2016-01-06         2         6
# 2025-09-17 19:43:22,085 - INFO - Cypher mapping for PROCESSED_BY:
# 2025-09-17 19:43:22,085 - INFO -   CSV: order_id -> staff_id
# 2025-09-17 19:43:22,085 - INFO -   Nodes: Order.order_id -> Staff.staff_id
# 2025-09-17 19:43:22,092 - INFO - Chunking PROCESSED_BY: 1615 records, contention=MEDIUM, batch_size=200
# 2025-09-17 19:43:22,143 - INFO - Created 17 chunks for PROCESSED_BY
# 2025-09-17 19:43:22,144 - INFO - Processing first 3 chunks sequentially to reduce contention
# 2025-09-17 19:43:22,445 - INFO - Sequential PROCESSED_BY chunk 0: 50 committed
# 2025-09-17 19:43:22,742 - INFO - Sequential PROCESSED_BY chunk 1: 50 committed
# 2025-09-17 19:43:23,055 - INFO - Sequential PROCESSED_BY chunk 2: 50 committed
# 2025-09-17 19:43:23,385 - INFO - Concurrent PROCESSED_BY chunk 0: 50 committed in 0.22s (230 records/s)
# 2025-09-17 19:43:23,438 - INFO - Concurrent PROCESSED_BY chunk 1: 50 committed in 0.22s (230 records/s)
# 2025-09-17 19:43:23,650 - INFO - Concurrent PROCESSED_BY chunk 2: 50 committed in 0.15s (325 records/s)
# 2025-09-17 19:43:23,757 - INFO - Concurrent PROCESSED_BY chunk 3: 50 committed in 0.16s (312 records/s)
# 2025-09-17 19:43:23,987 - INFO - Concurrent PROCESSED_BY chunk 4: 50 committed in 0.14s (367 records/s)
# 2025-09-17 19:43:24,191 - INFO - Concurrent PROCESSED_BY chunk 5: 50 committed in 0.17s (287 records/s)
# 2025-09-17 19:43:24,479 - INFO - Concurrent PROCESSED_BY chunk 6: 50 committed in 0.18s (279 records/s)
# 2025-09-17 19:43:24,816 - INFO - Concurrent PROCESSED_BY chunk 7: 50 committed in 0.27s (188 records/s)
# 2025-09-17 19:43:25,070 - INFO - Concurrent PROCESSED_BY chunk 8: 3 committed in 0.18s (17 records/s)
# 2025-09-17 19:43:25,694 - INFO - Concurrent PROCESSED_BY chunk 9: 240 committed in 0.43s (563 records/s)
# 2025-09-17 19:43:25,895 - INFO - Concurrent PROCESSED_BY chunk 10: 196 committed in 0.32s (605 records/s)
# 2025-09-17 19:43:26,552 - INFO - Concurrent PROCESSED_BY chunk 11: 209 committed in 0.29s (711 records/s)
# 2025-09-17 19:43:26,763 - INFO - Concurrent PROCESSED_BY chunk 12: 197 committed in 0.26s (761 records/s)
# 2025-09-17 19:43:27,468 - INFO - Concurrent PROCESSED_BY chunk 13: 220 committed in 0.27s (828 records/s)
# 2025-09-17 19:43:27,586 - INFO - PROCESSED_BY completed: 1615 committed (1615 verified), 0 failed, 100.0% success, 284 records/s, avg retries: 0.0
# 2025-09-17 19:43:27,733 - INFO - PROCESSED_BY: 1615 relationships created (1615 verified)
# 2025-09-17 19:43:28,242 - INFO -
# Processing Relationship 4/9: PLACED_AT
# 2025-09-17 19:43:28,242 - INFO -    Source: Order -> Target: Store
# 2025-09-17 19:43:28,242 - INFO -    Keys: order_id -> store_id
# 2025-09-17 19:43:28,242 - INFO -    Table: orders
# 2025-09-17 19:43:28,242 - INFO - Processing PLACED_AT with enhanced retry mechanisms
# 2025-09-17 19:43:28,443 - INFO - Node validation for PLACED_AT: Order=1615, Store=3
# 2025-09-17 19:43:28,443 - INFO - Loaded 1615 records from bike_files/orders.csv
# 2025-09-17 19:43:28,443 - INFO - CSV columns: ['order_id', 'customer_id', 'order_status', 'order_date', 'required_date', 'shipped_date', 'store_id', 'staff_id']
# 2025-09-17 19:43:28,443 - INFO - Preprocessed data: 1615 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:43:28,443 - INFO - Sample data:
#    order_id  customer_id  order_status  order_date required_date shipped_date  store_id  staff_id
# 0         1          259             4  2016-01-01    2016-01-03   2016-01-03         1         2
# 1         2         1212             4  2016-01-01    2016-01-04   2016-01-03         2         6
# 2         3          523             4  2016-01-02    2016-01-05   2016-01-03         2         7
# 3         4          175             4  2016-01-03    2016-01-04   2016-01-05         1         3
# 4         5         1324             4  2016-01-03    2016-01-06   2016-01-06         2         6
# 2025-09-17 19:43:28,443 - INFO - Cypher mapping for PLACED_AT:
# 2025-09-17 19:43:28,459 - INFO -   CSV: order_id -> store_id
# 2025-09-17 19:43:28,459 - INFO -   Nodes: Order.order_id -> Store.store_id
# 2025-09-17 19:43:28,463 - INFO - Chunking PLACED_AT: 1615 records, contention=MEDIUM, batch_size=200
# 2025-09-17 19:43:28,508 - INFO - Created 24 chunks for PLACED_AT
# 2025-09-17 19:43:28,508 - INFO - Processing first 3 chunks sequentially to reduce contention
# 2025-09-17 19:43:28,781 - INFO - Sequential PLACED_AT chunk 0: 50 committed
# 2025-09-17 19:43:29,759 - INFO - Sequential PLACED_AT chunk 1: 50 committed
# 2025-09-17 19:43:30,042 - INFO - Sequential PLACED_AT chunk 2: 50 committed
# 2025-09-17 19:43:30,332 - INFO - Concurrent PLACED_AT chunk 0: 50 committed in 0.18s (285 records/s)
# 2025-09-17 19:43:30,377 - INFO - Concurrent PLACED_AT chunk 1: 50 committed in 0.17s (298 records/s)
# 2025-09-17 19:43:30,608 - INFO - Concurrent PLACED_AT chunk 2: 50 committed in 0.18s (286 records/s)
# 2025-09-17 19:43:30,732 - INFO - Concurrent PLACED_AT chunk 3: 50 committed in 0.20s (245 records/s)
# 2025-09-17 19:43:30,950 - INFO - Concurrent PLACED_AT chunk 4: 50 committed in 0.14s (353 records/s)
# 2025-09-17 19:43:31,191 - INFO - Concurrent PLACED_AT chunk 5: 50 committed in 0.21s (240 records/s)
# 2025-09-17 19:43:31,440 - INFO - Concurrent PLACED_AT chunk 6: 50 committed in 0.19s (265 records/s)
# 2025-09-17 19:43:31,721 - INFO - Concurrent PLACED_AT chunk 7: 50 committed in 0.16s (305 records/s)
# 2025-09-17 19:43:32,018 - INFO - Concurrent PLACED_AT chunk 8: 50 committed in 0.17s (288 records/s)
# 2025-09-17 19:43:32,361 - INFO - Concurrent PLACED_AT chunk 9: 50 committed in 0.16s (312 records/s)
# 2025-09-17 19:43:32,690 - INFO - Concurrent PLACED_AT chunk 10: 50 committed in 0.17s (294 records/s)
# 2025-09-17 19:43:33,059 - INFO - Concurrent PLACED_AT chunk 11: 50 committed in 0.15s (337 records/s)
# 2025-09-17 19:43:33,411 - INFO - Concurrent PLACED_AT chunk 12: 50 committed in 0.12s (418 records/s)
# 2025-09-17 19:43:33,915 - INFO - Concurrent PLACED_AT chunk 13: 50 committed in 0.19s (262 records/s)
# 2025-09-17 19:43:34,344 - INFO - Concurrent PLACED_AT chunk 14: 50 committed in 0.22s (229 records/s)
# 2025-09-17 19:43:34,832 - INFO - Concurrent PLACED_AT chunk 15: 50 committed in 0.16s (318 records/s)
# 2025-09-17 19:43:35,272 - INFO - Concurrent PLACED_AT chunk 16: 50 committed in 0.13s (396 records/s)
# 2025-09-17 19:43:35,857 - INFO - Concurrent PLACED_AT chunk 17: 50 committed in 0.17s (289 records/s)
# 2025-09-17 19:43:36,314 - INFO - Concurrent PLACED_AT chunk 18: 43 committed in 0.13s (325 records/s)
# 2025-09-17 19:43:37,182 - INFO - Concurrent PLACED_AT chunk 19: 269 committed in 0.37s (723 records/s)
# 2025-09-17 19:43:37,575 - INFO - Concurrent PLACED_AT chunk 20: 253 committed in 0.26s (971 records/s)
# 2025-09-17 19:43:37,681 - INFO - PLACED_AT completed: 1615 committed (1615 verified), 0 failed, 100.0% success, 171 records/s, avg retries: 0.0
# 2025-09-17 19:43:37,800 - INFO - PLACED_AT: 1615 relationships created (1615 verified)
# 2025-09-17 19:43:38,302 - INFO -
# Processing Relationship 5/9: PLACED_BY
# 2025-09-17 19:43:38,302 - INFO -    Source: Order -> Target: Customer
# 2025-09-17 19:43:38,303 - INFO -    Keys: order_id -> customer_id
# 2025-09-17 19:43:38,303 - INFO -    Table: orders
# 2025-09-17 19:43:38,303 - INFO - Processing PLACED_BY with enhanced retry mechanisms
# 2025-09-17 19:43:38,488 - INFO - Node validation for PLACED_BY: Order=1615, Customer=1445
# 2025-09-17 19:43:38,488 - INFO - Loaded 1615 records from bike_files/orders.csv
# 2025-09-17 19:43:38,488 - INFO - CSV columns: ['order_id', 'customer_id', 'order_status', 'order_date', 'required_date', 'shipped_date', 'store_id', 'staff_id']
# 2025-09-17 19:43:38,488 - INFO - Preprocessed data: 1615 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:43:38,504 - INFO - Sample data:
#    order_id  customer_id  order_status  order_date required_date shipped_date  store_id  staff_id
# 0         1          259             4  2016-01-01    2016-01-03   2016-01-03         1         2
# 1         2         1212             4  2016-01-01    2016-01-04   2016-01-03         2         6
# 2         3          523             4  2016-01-02    2016-01-05   2016-01-03         2         7
# 3         4          175             4  2016-01-03    2016-01-04   2016-01-05         1         3
# 4         5         1324             4  2016-01-03    2016-01-06   2016-01-06         2         6
# 2025-09-17 19:43:38,504 - INFO - Cypher mapping for PLACED_BY:
# 2025-09-17 19:43:38,504 - INFO -   CSV: order_id -> customer_id
# 2025-09-17 19:43:38,504 - INFO -   Nodes: Order.order_id -> Customer.customer_id
# 2025-09-17 19:43:38,510 - INFO - Chunking PLACED_BY: 1615 records, contention=MEDIUM, batch_size=200
# 2025-09-17 19:43:38,557 - INFO - Created 13 chunks for PLACED_BY
# 2025-09-17 19:43:38,557 - INFO - Processing first 3 chunks sequentially to reduce contention
# 2025-09-17 19:43:38,785 - INFO - Sequential PLACED_BY chunk 0: 50 committed
# 2025-09-17 19:43:39,088 - INFO - Sequential PLACED_BY chunk 1: 50 committed
# 2025-09-17 19:43:39,381 - INFO - Sequential PLACED_BY chunk 2: 50 committed
# 2025-09-17 19:43:39,670 - INFO - Concurrent PLACED_BY chunk 0: 50 committed in 0.18s (282 records/s)
# 2025-09-17 19:43:39,731 - INFO - Concurrent PLACED_BY chunk 1: 50 committed in 0.18s (271 records/s)
# 2025-09-17 19:43:40,006 - INFO - Concurrent PLACED_BY chunk 2: 50 committed in 0.23s (213 records/s)
# 2025-09-17 19:43:40,087 - INFO - Concurrent PLACED_BY chunk 3: 1 committed in 0.19s (5 records/s)
# 2025-09-17 19:43:40,763 - INFO - Concurrent PLACED_BY chunk 4: 222 committed in 0.55s (405 records/s)
# 2025-09-17 19:43:40,780 - INFO - Concurrent PLACED_BY chunk 5: 217 committed in 0.43s (503 records/s)
# 2025-09-17 19:43:41,648 - INFO - Concurrent PLACED_BY chunk 6: 205 committed in 0.57s (357 records/s)
# 2025-09-17 19:43:41,753 - INFO - Concurrent PLACED_BY chunk 7: 222 committed in 0.62s (357 records/s)
# 2025-09-17 19:43:42,450 - INFO - Concurrent PLACED_BY chunk 8: 236 committed in 0.40s (587 records/s)
# 2025-09-17 19:43:42,741 - INFO - Concurrent PLACED_BY chunk 9: 212 committed in 0.53s (400 records/s)
# 2025-09-17 19:43:42,856 - INFO - PLACED_BY completed: 1615 committed (1615 verified), 0 failed, 100.0% success, 355 records/s, avg retries: 0.0
# 2025-09-17 19:43:42,980 - INFO - PLACED_BY: 1615 relationships created (1615 verified)
# 2025-09-17 19:43:43,482 - INFO -
# Processing Relationship 6/9: CONTAINS_ITEM
# 2025-09-17 19:43:43,482 - INFO -    Source: Order -> Target: Product
# 2025-09-17 19:43:43,483 - INFO -    Keys: order_id -> product_id
# 2025-09-17 19:43:43,483 - INFO -    Table: order_items
# 2025-09-17 19:43:43,483 - INFO - Processing CONTAINS_ITEM with enhanced retry mechanisms
# 2025-09-17 19:43:43,667 - INFO - Node validation for CONTAINS_ITEM: Order=1615, Product=321
# 2025-09-17 19:43:43,686 - INFO - Loaded 4722 records from bike_files/order_items.csv
# 2025-09-17 19:43:43,686 - INFO - CSV columns: ['order_id', 'item_id', 'product_id', 'quantity', 'list_price', 'discount']
# 2025-09-17 19:43:43,690 - INFO - Preprocessed data: 4722 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:43:43,693 - INFO - Sample data:
#    order_id  item_id  product_id  quantity  list_price  discount
# 4         1        5           4         1     2899.99      0.20
# 1         1        2           8         2     1799.99      0.07
# 2         1        3          10         2     1549.00      0.05
# 3         1        4          16         2      599.99      0.05
# 0         1        1          20         1      599.99      0.20
# 2025-09-17 19:43:43,693 - INFO - Cypher mapping for CONTAINS_ITEM:
# 2025-09-17 19:43:43,694 - INFO -   CSV: order_id -> product_id
# 2025-09-17 19:43:43,695 - INFO -   Nodes: Order.order_id -> Product.product_id
# 2025-09-17 19:43:43,699 - INFO - Chunking CONTAINS_ITEM: 4722 records, contention=HIGH, batch_size=200
# 2025-09-17 19:43:43,738 - INFO - Created 112 chunks for CONTAINS_ITEM
# 2025-09-17 19:43:43,738 - INFO - Processing first 3 chunks sequentially to reduce contention
# 2025-09-17 19:43:44,025 - INFO - Sequential CONTAINS_ITEM chunk 0: 5 committed
# 2025-09-17 19:43:44,277 - INFO - Sequential CONTAINS_ITEM chunk 1: 5 committed
# 2025-09-17 19:43:44,528 - INFO - Sequential CONTAINS_ITEM chunk 2: 5 committed
# 2025-09-17 19:43:44,896 - INFO - Concurrent CONTAINS_ITEM chunk 1: 5 committed in 0.21s (23 records/s)
# 2025-09-17 19:43:44,896 - INFO - Concurrent CONTAINS_ITEM chunk 0: 5 committed in 0.27s (19 records/s)
# 2025-09-17 19:43:45,252 - INFO - Concurrent CONTAINS_ITEM chunk 2: 25 committed in 0.25s (101 records/s)
# 2025-09-17 19:43:45,280 - INFO - Concurrent CONTAINS_ITEM chunk 3: 25 committed in 0.22s (112 records/s)
# 2025-09-17 19:43:45,583 - INFO - Concurrent CONTAINS_ITEM chunk 4: 25 committed in 0.13s (190 records/s)
# 2025-09-17 19:43:45,650 - INFO - Concurrent CONTAINS_ITEM chunk 5: 25 committed in 0.12s (210 records/s)
# 2025-09-17 19:43:46,077 - INFO - Concurrent CONTAINS_ITEM chunk 6: 3 committed in 0.19s (16 records/s)
# 2025-09-17 19:43:46,190 - INFO - Concurrent CONTAINS_ITEM chunk 7: 25 committed in 0.19s (134 records/s)
# 2025-09-17 19:43:46,771 - INFO - Concurrent CONTAINS_ITEM chunk 9: 25 committed in 0.12s (202 records/s)
# 2025-09-17 19:43:47,072 - INFO - Concurrent CONTAINS_ITEM chunk 8: 25 committed in 0.59s (42 records/s)
# 2025-09-17 19:43:47,399 - INFO - Concurrent CONTAINS_ITEM chunk 10: 25 committed in 0.13s (199 records/s)
# 2025-09-17 19:43:47,771 - INFO - Concurrent CONTAINS_ITEM chunk 11: 2 committed in 0.15s (14 records/s)
# 2025-09-17 19:43:48,160 - INFO - Concurrent CONTAINS_ITEM chunk 12: 25 committed in 0.16s (156 records/s)
# 2025-09-17 19:43:48,562 - INFO - Concurrent CONTAINS_ITEM chunk 13: 25 committed in 0.14s (179 records/s)
# 2025-09-17 19:43:49,084 - INFO - Concurrent CONTAINS_ITEM chunk 14: 25 committed in 0.22s (112 records/s)
# 2025-09-17 19:43:49,452 - INFO - Concurrent CONTAINS_ITEM chunk 15: 25 committed in 0.14s (180 records/s)
# 2025-09-17 19:43:50,181 - INFO - Concurrent CONTAINS_ITEM chunk 16: 1 committed in 0.29s (3 records/s)
# 2025-09-17 19:43:50,465 - INFO - Concurrent CONTAINS_ITEM chunk 17: 25 committed in 0.16s (153 records/s)
# 2025-09-17 19:43:51,223 - INFO - Concurrent CONTAINS_ITEM chunk 18: 25 committed in 0.14s (180 records/s)
# 2025-09-17 19:43:51,570 - INFO - Concurrent CONTAINS_ITEM chunk 19: 25 committed in 0.15s (163 records/s)
# 2025-09-17 19:43:52,391 - INFO - Concurrent CONTAINS_ITEM chunk 20: 25 committed in 0.16s (152 records/s)
# 2025-09-17 19:43:52,855 - INFO - Concurrent CONTAINS_ITEM chunk 21: 50 committed in 0.23s (216 records/s)
# 2025-09-17 19:43:53,688 - INFO - Concurrent CONTAINS_ITEM chunk 22: 50 committed in 0.20s (255 records/s)
# 2025-09-17 19:43:54,147 - INFO - Concurrent CONTAINS_ITEM chunk 23: 49 committed in 0.14s (346 records/s)
# 2025-09-17 19:43:55,059 - INFO - Concurrent CONTAINS_ITEM chunk 24: 49 committed in 0.16s (298 records/s)
# 2025-09-17 19:43:55,642 - INFO - Concurrent CONTAINS_ITEM chunk 25: 48 committed in 0.24s (200 records/s)
# 2025-09-17 19:43:56,518 - INFO - Concurrent CONTAINS_ITEM chunk 26: 47 committed in 0.16s (298 records/s)
# 2025-09-17 19:43:57,174 - INFO - Concurrent CONTAINS_ITEM chunk 27: 50 committed in 0.18s (277 records/s)
# 2025-09-17 19:43:58,061 - INFO - Concurrent CONTAINS_ITEM chunk 28: 49 committed in 0.14s (345 records/s)
# 2025-09-17 19:43:58,795 - INFO - Concurrent CONTAINS_ITEM chunk 29: 48 committed in 0.17s (281 records/s)
# 2025-09-17 19:43:59,778 - INFO - Concurrent CONTAINS_ITEM chunk 30: 50 committed in 0.22s (232 records/s)
# 2025-09-17 19:44:00,598 - INFO - Concurrent CONTAINS_ITEM chunk 31: 49 committed in 0.25s (195 records/s)
# 2025-09-17 19:44:01,584 - INFO - Concurrent CONTAINS_ITEM chunk 32: 50 committed in 0.21s (243 records/s)
# 2025-09-17 19:44:02,445 - INFO - Concurrent CONTAINS_ITEM chunk 33: 50 committed in 0.20s (254 records/s)
# 2025-09-17 19:44:03,432 - INFO - Concurrent CONTAINS_ITEM chunk 34: 50 committed in 0.14s (347 records/s)
# 2025-09-17 19:44:04,411 - INFO - Concurrent CONTAINS_ITEM chunk 35: 47 committed in 0.21s (219 records/s)
# 2025-09-17 19:44:05,389 - INFO - Concurrent CONTAINS_ITEM chunk 36: 50 committed in 0.16s (318 records/s)
# 2025-09-17 19:44:06,459 - INFO - Concurrent CONTAINS_ITEM chunk 37: 50 committed in 0.20s (253 records/s)
# 2025-09-17 19:44:07,486 - INFO - Concurrent CONTAINS_ITEM chunk 38: 48 committed in 0.20s (245 records/s)
# 2025-09-17 19:44:08,598 - INFO - Concurrent CONTAINS_ITEM chunk 39: 49 committed in 0.19s (263 records/s)
# 2025-09-17 19:44:09,646 - INFO - Concurrent CONTAINS_ITEM chunk 40: 50 committed in 0.15s (330 records/s)
# 2025-09-17 19:44:10,918 - INFO - Concurrent CONTAINS_ITEM chunk 41: 47 committed in 0.27s (176 records/s)
# 2025-09-17 19:44:11,931 - INFO - Concurrent CONTAINS_ITEM chunk 42: 49 committed in 0.18s (265 records/s)
# 2025-09-17 19:44:13,250 - INFO - Concurrent CONTAINS_ITEM chunk 43: 50 committed in 0.18s (280 records/s)
# 2025-09-17 19:44:14,320 - INFO - Concurrent CONTAINS_ITEM chunk 44: 47 committed in 0.18s (257 records/s)
# 2025-09-17 19:44:15,797 - INFO - Concurrent CONTAINS_ITEM chunk 45: 50 committed in 0.29s (171 records/s)
# 2025-09-17 19:44:16,800 - INFO - Concurrent CONTAINS_ITEM chunk 46: 47 committed in 0.18s (268 records/s)
# 2025-09-17 19:44:18,327 - INFO - Concurrent CONTAINS_ITEM chunk 47: 49 committed in 0.18s (275 records/s)
# 2025-09-17 19:44:19,414 - INFO - Concurrent CONTAINS_ITEM chunk 48: 49 committed in 0.21s (231 records/s)
# 2025-09-17 19:44:21,070 - INFO - Concurrent CONTAINS_ITEM chunk 49: 49 committed in 0.29s (168 records/s)
# 2025-09-17 19:44:22,132 - INFO - Concurrent CONTAINS_ITEM chunk 50: 50 committed in 0.22s (231 records/s)
# 2025-09-17 19:44:23,827 - INFO - Concurrent CONTAINS_ITEM chunk 51: 49 committed in 0.21s (238 records/s)
# 2025-09-17 19:44:24,890 - INFO - Concurrent CONTAINS_ITEM chunk 52: 50 committed in 0.16s (318 records/s)
# 2025-09-17 19:44:26,640 - INFO - Concurrent CONTAINS_ITEM chunk 53: 50 committed in 0.16s (317 records/s)
# 2025-09-17 19:44:27,995 - INFO - Concurrent CONTAINS_ITEM chunk 54: 49 committed in 0.40s (121 records/s)
# 2025-09-17 19:44:29,542 - INFO - Concurrent CONTAINS_ITEM chunk 55: 50 committed in 0.15s (332 records/s)
# 2025-09-17 19:44:30,946 - INFO - Concurrent CONTAINS_ITEM chunk 56: 50 committed in 0.15s (332 records/s)
# 2025-09-17 19:44:32,661 - INFO - Concurrent CONTAINS_ITEM chunk 57: 48 committed in 0.27s (180 records/s)
# 2025-09-17 19:44:34,057 - INFO - Concurrent CONTAINS_ITEM chunk 58: 47 committed in 0.21s (224 records/s)
# 2025-09-17 19:44:35,800 - INFO - Concurrent CONTAINS_ITEM chunk 59: 47 committed in 0.19s (254 records/s)
# 2025-09-17 19:44:37,204 - INFO - Concurrent CONTAINS_ITEM chunk 60: 47 committed in 0.15s (321 records/s)
# 2025-09-17 19:44:39,076 - INFO - Concurrent CONTAINS_ITEM chunk 61: 49 committed in 0.22s (218 records/s)
# 2025-09-17 19:44:40,458 - INFO - Concurrent CONTAINS_ITEM chunk 62: 50 committed in 0.15s (329 records/s)
# 2025-09-17 19:44:42,354 - INFO - Concurrent CONTAINS_ITEM chunk 63: 46 committed in 0.13s (365 records/s)
# 2025-09-17 19:44:43,961 - INFO - Concurrent CONTAINS_ITEM chunk 64: 50 committed in 0.30s (166 records/s)
# 2025-09-17 19:44:45,772 - INFO - Concurrent CONTAINS_ITEM chunk 65: 49 committed in 0.16s (304 records/s)
# 2025-09-17 19:44:47,536 - INFO - Concurrent CONTAINS_ITEM chunk 66: 46 committed in 0.27s (168 records/s)
# 2025-09-17 19:44:49,361 - INFO - Concurrent CONTAINS_ITEM chunk 67: 50 committed in 0.23s (214 records/s)
# 2025-09-17 19:44:51,132 - INFO - Concurrent CONTAINS_ITEM chunk 68: 49 committed in 0.19s (251 records/s)
# 2025-09-17 19:44:52,986 - INFO - Concurrent CONTAINS_ITEM chunk 69: 50 committed in 0.17s (296 records/s)
# 2025-09-17 19:44:54,889 - INFO - Concurrent CONTAINS_ITEM chunk 70: 47 committed in 0.26s (183 records/s)
# 2025-09-17 19:44:56,711 - INFO - Concurrent CONTAINS_ITEM chunk 71: 49 committed in 0.17s (290 records/s)
# 2025-09-17 19:44:58,646 - INFO - Concurrent CONTAINS_ITEM chunk 72: 50 committed in 0.15s (330 records/s)
# 2025-09-17 19:45:00,515 - INFO - Concurrent CONTAINS_ITEM chunk 73: 50 committed in 0.15s (324 records/s)
# 2025-09-17 19:45:02,487 - INFO - Concurrent CONTAINS_ITEM chunk 74: 49 committed in 0.13s (380 records/s)
# 2025-09-17 19:45:04,452 - INFO - Concurrent CONTAINS_ITEM chunk 75: 49 committed in 0.19s (263 records/s)
# 2025-09-17 19:45:06,551 - INFO - Concurrent CONTAINS_ITEM chunk 76: 49 committed in 0.26s (186 records/s)
# 2025-09-17 19:45:08,445 - INFO - Concurrent CONTAINS_ITEM chunk 77: 50 committed in 0.14s (351 records/s)
# 2025-09-17 19:45:10,646 - INFO - Concurrent CONTAINS_ITEM chunk 78: 48 committed in 0.19s (251 records/s)
# 2025-09-17 19:45:12,618 - INFO - Concurrent CONTAINS_ITEM chunk 79: 50 committed in 0.22s (226 records/s)
# 2025-09-17 19:45:14,809 - INFO - Concurrent CONTAINS_ITEM chunk 80: 49 committed in 0.16s (301 records/s)
# 2025-09-17 19:45:16,930 - INFO - Concurrent CONTAINS_ITEM chunk 81: 48 committed in 0.26s (184 records/s)
# 2025-09-17 19:45:19,092 - INFO - Concurrent CONTAINS_ITEM chunk 82: 50 committed in 0.18s (273 records/s)
# 2025-09-17 19:45:21,223 - INFO - Concurrent CONTAINS_ITEM chunk 83: 47 committed in 0.14s (337 records/s)
# 2025-09-17 19:45:23,445 - INFO - Concurrent CONTAINS_ITEM chunk 84: 49 committed in 0.15s (323 records/s)
# 2025-09-17 19:45:25,678 - INFO - Concurrent CONTAINS_ITEM chunk 85: 46 committed in 0.20s (225 records/s)
# 2025-09-17 19:45:27,978 - INFO - Concurrent CONTAINS_ITEM chunk 86: 49 committed in 0.23s (213 records/s)
# 2025-09-17 19:45:30,200 - INFO - Concurrent CONTAINS_ITEM chunk 87: 48 committed in 0.16s (294 records/s)
# 2025-09-17 19:45:32,518 - INFO - Concurrent CONTAINS_ITEM chunk 88: 50 committed in 0.14s (364 records/s)
# 2025-09-17 19:45:34,847 - INFO - Concurrent CONTAINS_ITEM chunk 89: 47 committed in 0.19s (248 records/s)
# 2025-09-17 19:45:37,201 - INFO - Concurrent CONTAINS_ITEM chunk 90: 48 committed in 0.17s (286 records/s)
# 2025-09-17 19:45:39,667 - INFO - Concurrent CONTAINS_ITEM chunk 91: 48 committed in 0.26s (182 records/s)
# 2025-09-17 19:45:42,001 - INFO - Concurrent CONTAINS_ITEM chunk 92: 50 committed in 0.20s (252 records/s)
# 2025-09-17 19:45:44,493 - INFO - Concurrent CONTAINS_ITEM chunk 93: 47 committed in 0.17s (269 records/s)
# 2025-09-17 19:45:46,895 - INFO - Concurrent CONTAINS_ITEM chunk 94: 48 committed in 0.19s (252 records/s)
# 2025-09-17 19:45:49,390 - INFO - Concurrent CONTAINS_ITEM chunk 95: 48 committed in 0.15s (328 records/s)
# 2025-09-17 19:45:51,911 - INFO - Concurrent CONTAINS_ITEM chunk 96: 50 committed in 0.21s (233 records/s)
# 2025-09-17 19:45:54,430 - INFO - Concurrent CONTAINS_ITEM chunk 97: 47 committed in 0.19s (252 records/s)
# 2025-09-17 19:45:57,030 - INFO - Concurrent CONTAINS_ITEM chunk 98: 49 committed in 0.22s (224 records/s)
# 2025-09-17 19:45:59,537 - INFO - Concurrent CONTAINS_ITEM chunk 99: 47 committed in 0.16s (301 records/s)
# 2025-09-17 19:46:02,693 - INFO - Concurrent CONTAINS_ITEM chunk 100: 47 committed in 0.66s (71 records/s)
# 2025-09-17 19:46:04,811 - INFO - Concurrent CONTAINS_ITEM chunk 101: 46 committed in 0.22s (205 records/s)
# 2025-09-17 19:46:07,972 - INFO - Concurrent CONTAINS_ITEM chunk 102: 50 committed in 0.17s (294 records/s)
# 2025-09-17 19:46:10,107 - INFO - Concurrent CONTAINS_ITEM chunk 103: 48 committed in 0.15s (331 records/s)
# 2025-09-17 19:46:13,451 - INFO - Concurrent CONTAINS_ITEM chunk 104: 50 committed in 0.27s (184 records/s)
# 2025-09-17 19:46:15,482 - INFO - Concurrent CONTAINS_ITEM chunk 105: 50 committed in 0.12s (407 records/s)
# 2025-09-17 19:46:18,966 - INFO - Concurrent CONTAINS_ITEM chunk 106: 49 committed in 0.21s (229 records/s)
# 2025-09-17 19:46:20,997 - INFO - Concurrent CONTAINS_ITEM chunk 107: 49 committed in 0.16s (316 records/s)
# 2025-09-17 19:46:24,611 - INFO - Concurrent CONTAINS_ITEM chunk 108: 50 committed in 0.24s (210 records/s)
# 2025-09-17 19:46:24,717 - INFO - CONTAINS_ITEM completed: 4722 committed (4722 verified), 0 failed, 100.0% success, 29 records/s, avg retries: 0.0
# 2025-09-17 19:46:24,826 - INFO - CONTAINS_ITEM: 4722 relationships created (4722 verified)
# 2025-09-17 19:46:25,328 - INFO -
# Processing Relationship 7/9: BELONGS_TO_CATEGORY
# 2025-09-17 19:46:25,328 - INFO -    Source: Product -> Target: Category
# 2025-09-17 19:46:25,328 - INFO -    Keys: product_id -> category_id
# 2025-09-17 19:46:25,328 - INFO -    Table: products
# 2025-09-17 19:46:25,328 - INFO - Processing BELONGS_TO_CATEGORY with enhanced retry mechanisms
# 2025-09-17 19:46:25,524 - INFO - Node validation for BELONGS_TO_CATEGORY: Product=321, Category=7
# 2025-09-17 19:46:25,526 - INFO - Loaded 321 records from bike_files/products.csv
# 2025-09-17 19:46:25,527 - INFO - CSV columns: ['product_id', 'product_name', 'brand_id', 'category_id', 'model_year', 'list_price']
# 2025-09-17 19:46:25,529 - INFO - Preprocessed data: 321 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:46:25,529 - INFO - Sample data:
#    product_id                        product_name  brand_id  category_id  model_year  list_price
# 0           1                     Trek 820 - 2016         9            6        2016      379.99
# 1           2  Ritchey Timberwolf Frameset - 2016         5            6        2016      749.99
# 2           3     Surly Wednesday Frameset - 2016         8            6        2016      999.99
# 3           4            Trek Fuel EX 8 29 - 2016         9            6        2016     2899.99
# 4           5        Heller Shagamaw Frame - 2016         3            6        2016     1320.99
# 2025-09-17 19:46:25,529 - INFO - Cypher mapping for BELONGS_TO_CATEGORY:
# 2025-09-17 19:46:25,529 - INFO -   CSV: product_id -> category_id
# 2025-09-17 19:46:25,529 - INFO -   Nodes: Product.product_id -> Category.category_id
# 2025-09-17 19:46:25,529 - INFO - Chunking BELONGS_TO_CATEGORY: 321 records, contention=MEDIUM, batch_size=200
# 2025-09-17 19:46:25,529 - INFO - Created 4 chunks for BELONGS_TO_CATEGORY
# 2025-09-17 19:46:25,738 - INFO - Concurrent BELONGS_TO_CATEGORY chunk 0: 100 committed in 0.21s (477 records/s)
# 2025-09-17 19:46:25,746 - INFO - Concurrent BELONGS_TO_CATEGORY chunk 1: 100 committed in 0.16s (643 records/s)
# 2025-09-17 19:46:26,058 - INFO - Concurrent BELONGS_TO_CATEGORY chunk 3: 21 committed in 0.15s (139 records/s)
# 2025-09-17 19:46:26,072 - INFO - Concurrent BELONGS_TO_CATEGORY chunk 2: 100 committed in 0.23s (429 records/s)
# 2025-09-17 19:46:26,172 - INFO - BELONGS_TO_CATEGORY completed: 321 committed (321 verified), 0 failed, 100.0% success, 380 records/s, avg retries: 0.0
# 2025-09-17 19:46:26,279 - INFO - BELONGS_TO_CATEGORY: 321 relationships created (321 verified)
# 2025-09-17 19:46:26,781 - INFO -
# Processing Relationship 8/9: BELONGS_TO_BRAND
# 2025-09-17 19:46:26,781 - INFO -    Source: Product -> Target: Brand
# 2025-09-17 19:46:26,781 - INFO -    Keys: product_id -> brand_id
# 2025-09-17 19:46:26,781 - INFO -    Table: products
# 2025-09-17 19:46:26,781 - INFO - Processing BELONGS_TO_BRAND with enhanced retry mechanisms
# 2025-09-17 19:46:26,965 - INFO - Node validation for BELONGS_TO_BRAND: Product=321, Brand=9
# 2025-09-17 19:46:26,965 - INFO - Loaded 321 records from bike_files/products.csv
# 2025-09-17 19:46:26,965 - INFO - CSV columns: ['product_id', 'product_name', 'brand_id', 'category_id', 'model_year', 'list_price']
# 2025-09-17 19:46:26,965 - INFO - Preprocessed data: 321 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:46:26,981 - INFO - Sample data:
#    product_id                        product_name  brand_id  category_id  model_year  list_price
# 0           1                     Trek 820 - 2016         9            6        2016      379.99
# 1           2  Ritchey Timberwolf Frameset - 2016         5            6        2016      749.99
# 2           3     Surly Wednesday Frameset - 2016         8            6        2016      999.99
# 3           4            Trek Fuel EX 8 29 - 2016         9            6        2016     2899.99
# 4           5        Heller Shagamaw Frame - 2016         3            6        2016     1320.99
# 2025-09-17 19:46:26,981 - INFO - Cypher mapping for BELONGS_TO_BRAND:
# 2025-09-17 19:46:26,981 - INFO -   CSV: product_id -> brand_id
# 2025-09-17 19:46:26,981 - INFO -   Nodes: Product.product_id -> Brand.brand_id
# 2025-09-17 19:46:26,981 - INFO - Chunking BELONGS_TO_BRAND: 321 records, contention=HIGH, batch_size=200
# 2025-09-17 19:46:26,981 - INFO - Created 4 chunks for BELONGS_TO_BRAND
# 2025-09-17 19:46:27,251 - INFO - Concurrent BELONGS_TO_BRAND chunk 0: 100 committed in 0.27s (372 records/s)
# 2025-09-17 19:46:27,295 - WARNING - Retryable error detected: {code: Neo.TransientError.Transaction.DeadlockDetected} {message: ForsetiClient[transactionId=264, clientId=5] can't acquire ExclusiveLock{owner=ForsetiClient[transactionId=263, clientId=4]} on NODE_RELATIONSHIP_GROUP_DELETE(25) because holders of that lock are waiting for ForsetiClient[transactionId=264, clientId=5].
#  Wait list:ExclusiveLock[
# Client[263] waits for []]}
# 2025-09-17 19:46:27,295 - WARNING - Attempt 1 failed for _execute_cypher_with_retry: Retryable database error: {code: Neo.TransientError.Transaction.DeadlockDetected} {message: ForsetiClient[transactionId=264, clientId=5] can't acquire ExclusiveLock{owner=ForsetiClient[transactionId=263, clientId=4]} on NODE_RELATIONSHIP_GROUP_DELETE(25) because holders of that lock are waiting for ForsetiClient[transactionId=264, clientId=5].
#  Wait list:ExclusiveLock[
# Client[263] waits for []]}. Retrying in 0.30s...
# 2025-09-17 19:46:27,487 - INFO - Concurrent BELONGS_TO_BRAND chunk 2: 100 committed in 0.14s (738 records/s)
# 2025-09-17 19:46:27,716 - INFO - Concurrent BELONGS_TO_BRAND chunk 1: 100 committed in 0.67s (148 records/s)
# 2025-09-17 19:46:27,747 - INFO - Concurrent BELONGS_TO_BRAND chunk 3: 21 committed in 0.11s (191 records/s)
# 2025-09-17 19:46:27,859 - INFO - BELONGS_TO_BRAND completed: 321 committed (321 verified), 0 failed, 100.0% success, 298 records/s, avg retries: 0.0
# 2025-09-17 19:46:27,966 - INFO - BELONGS_TO_BRAND: 321 relationships created (321 verified)
# 2025-09-17 19:46:28,468 - INFO -
# Processing Relationship 9/9: HAS_STOCK
# 2025-09-17 19:46:28,469 - INFO -    Source: Store -> Target: Product
# 2025-09-17 19:46:28,469 - INFO -    Keys: store_id -> product_id
# 2025-09-17 19:46:28,470 - INFO -    Table: stocks
# 2025-09-17 19:46:28,470 - INFO - Processing HAS_STOCK with enhanced retry mechanisms
# 2025-09-17 19:46:28,655 - INFO - Node validation for HAS_STOCK: Store=3, Product=321
# 2025-09-17 19:46:28,671 - INFO - Loaded 939 records from bike_files/stocks.csv
# 2025-09-17 19:46:28,671 - INFO - CSV columns: ['store_id', 'product_id', 'quantity']
# 2025-09-17 19:46:28,671 - INFO - Preprocessed data: 939 records, source_key dtype: int64, target_key dtype: int64
# 2025-09-17 19:46:28,671 - INFO - Sample data:
#    store_id  product_id  quantity
# 0         1           1        27
# 1         1           2         5
# 2         1           3         6
# 3         1           4        23
# 4         1           5        22
# 2025-09-17 19:46:28,671 - INFO - Cypher mapping for HAS_STOCK:
# 2025-09-17 19:46:28,671 - INFO -   CSV: store_id -> product_id
# 2025-09-17 19:46:28,671 - INFO -   Nodes: Store.store_id -> Product.product_id
# 2025-09-17 19:46:28,671 - INFO - Chunking HAS_STOCK: 939 records, contention=LOW, batch_size=200
# 2025-09-17 19:46:28,671 - INFO - Created 10 chunks for HAS_STOCK
# 2025-09-17 19:46:28,875 - INFO - Concurrent HAS_STOCK chunk 0: 100 committed in 0.20s (491 records/s)
# 2025-09-17 19:46:28,896 - INFO - Concurrent HAS_STOCK chunk 1: 100 committed in 0.16s (629 records/s)
# 2025-09-17 19:46:29,153 - INFO - Concurrent HAS_STOCK chunk 3: 100 committed in 0.11s (940 records/s)
# 2025-09-17 19:46:29,185 - INFO - Concurrent HAS_STOCK chunk 2: 100 committed in 0.20s (499 records/s)
# 2025-09-17 19:46:29,482 - INFO - Concurrent HAS_STOCK chunk 4: 100 committed in 0.12s (868 records/s)
# 2025-09-17 19:46:29,623 - INFO - Concurrent HAS_STOCK chunk 5: 100 committed in 0.18s (545 records/s)
# 2025-09-17 19:46:29,919 - INFO - Concurrent HAS_STOCK chunk 6: 100 committed in 0.14s (740 records/s)
# 2025-09-17 19:46:30,170 - INFO - Concurrent HAS_STOCK chunk 7: 100 committed in 0.19s (520 records/s)
# 2025-09-17 19:46:30,529 - INFO - Concurrent HAS_STOCK chunk 8: 100 committed in 0.20s (506 records/s)
# 2025-09-17 19:46:30,748 - INFO - Concurrent HAS_STOCK chunk 9: 39 committed in 0.13s (311 records/s)
# 2025-09-17 19:46:30,855 - INFO - HAS_STOCK completed: 939 committed (939 verified), 0 failed, 100.0% success, 394 records/s, avg retries: 0.0
# 2025-09-17 19:46:30,963 - INFO - HAS_STOCK: 939 relationships created (939 verified)
# 2025-09-17 19:46:30,963 - INFO -
# === FINAL DATABASE VERIFICATION ===
# 2025-09-17 19:46:31,214 - ERROR - Final verification failed: 'label'
# 2025-09-17 19:46:31,216 - INFO -
# ENHANCED EXECUTION COMPLETE!
# 2025-09-17 19:46:31,216 - INFO - Performance Summary:
# 2025-09-17 19:46:31,217 - INFO -    • Relationships: 9/9 successful
# 2025-09-17 19:46:31,217 - INFO -    • Records: 11,168 committed, 11,168 verified, 0 failed
# 2025-09-17 19:46:31,218 - INFO -    • Total retries: 0
# 2025-09-17 19:46:31,219 - INFO -    • Success rate: 100.0%
# 2025-09-17 19:46:31,219 - INFO -    • Duration: 192.35s
# 2025-09-17 19:46:31,220 - INFO -    • Throughput: 58 records/second
# 2025-09-17 19:46:31,221 - INFO -    • Final DB count: 0 relationships

# %%
from langraph_neo4j3 import AgentState, run_agent_workflow
user_input ="What is the total revenue per year?"

state: AgentState = {
        "question": user_input,
        "next_action": "",
        "cypher_errors": [],
        "database_records": [],
        "steps": [],
        "answer": "",
        "cypher_statement": ""
    }

result = run_agent_workflow(state,enhanced_graph)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#       2 user_input ="What is the total revenue per year?"
#       4 state: AgentState = {
#       5         "question": user_input,
#       6         "next_action": "",
#    (...)
#      11         "cypher_statement": ""
#      12     }
# ---> 14 result = run_agent_workflow(state,enhanced_graph)
#
# File e:\PwC_Pocs\GenAI\Project_1\graphDB\final\langraph_neo4j3.py:551, in run_agent_workflow(state, neo4j_graph)
#     547 langgraph.add_edge("generate_final_answer", END)
#     549 agent = langgraph.compile()
# --> 551 final_state = agent.invoke(state)
#     552 return final_state
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langgraph\pregel\__init__.py:2719, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2716 chunks: list[Union[dict[str, Any], Any]] = []
#    2717 interrupts: list[Interrupt] = []
# -> 2719 for chunk in self.stream(
#    2720     input,
#    2721     config,
#    2722     stream_mode=stream_mode,
#    2723     output_keys=output_keys,
#    2724     interrupt_before=interrupt_before,
#    2725     interrupt_after=interrupt_after,
#    2726     checkpoint_during=checkpoint_during,
#    2727     debug=debug,
#    2728     **kwargs,
#    2729 ):
#    2730     if stream_mode == "values":
#    2731         if (
#    2732             isinstance(chunk, dict)
#    2733             and (ints := chunk.get(INTERRUPT)) is not None
#    2734         ):
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langgraph\pregel\__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langgraph\pregel\runner.py:161, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     159 t = tasks[0]
#     160 try:
# --> 161     run_with_retry(
#     162         t,
#     163         retry_policy,
#     164         configurable={
#     165             CONFIG_KEY_CALL: partial(
#     166                 _call,
#     167                 weakref.ref(t),
#     168                 retry=retry_policy,
#     169                 futures=weakref.ref(futures),
#     170                 schedule_task=schedule_task,
#     171                 submit=self.submit,
#     172             ),
#     173         },
#     174     )
#     175     self.commit(t, None)
#     176 except Exception as exc:
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# File e:\PwC_Pocs\GenAI\Project_1\graphDB\final\langraph_neo4j3.py:438, in run_agent_workflow.<locals>.correct_cypher(state)
#     434 def correct_cypher(state: AgentState) -> AgentState:
#     435     """
#     436     Correct the Cypher statement based on the provided errors.
#     437     """
# --> 438     corrected_cypher = correct_cypher_chain.invoke(
#     439         {
#     440             "question": state.get("question"),
#     441             "errors": state.get("cypher_errors"),
#     442             "cypher": state.get("cypher_statement"),
#     443             "schema": enhanced_graph.schema,
#     444         }
#     445     )
#     447     return {
#     448         "next_action": "validate_cypher",
#     449         "cypher_statement": corrected_cypher,
#     450         "steps": ["correct_cypher"],
#     451     }
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_core\runnables\base.py:3049, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3047                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3048             else:
# -> 3049                 input_ = context.run(step.invoke, input_, config)
#    3050 # finish the root run
#    3051 except BaseException as e:
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_core\language_models\chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)
#     378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_core\language_models\chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)
#    1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_core\language_models\chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_core\language_models\chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_google_genai\chat_models.py:961, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#     935 def _generate(
#     936     self,
#     937     messages: List[BaseMessage],
#    (...)
#     948     **kwargs: Any,
#     949 ) -> ChatResult:
#     950     request = self._prepare_request(
#     951         messages,
#     952         stop=stop,
#    (...)
#     959         tool_choice=tool_choice,
#     960     )
# --> 961     response: GenerateContentResponse = _chat_with_retry(
#     962         request=request,
#     963         **kwargs,
#     964         generation_method=self.client.generate_content,
#     965         metadata=self.default_metadata,
#     966     )
#     967     return _response_to_result(response)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_google_genai\chat_models.py:196, in _chat_with_retry(generation_method, **kwargs)
#     193     except Exception as e:
#     194         raise e
# --> 196 return _chat_with_retry(**kwargs)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\tenacity\__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\langchain_google_genai\chat_models.py:178, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     175 @retry_decorator
#     176 def _chat_with_retry(**kwargs: Any) -> Any:
#     177     try:
# --> 178         return generation_method(**kwargs)
#     179     # Do not retry for these errors.
#     180     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\grpc\_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\grpc\_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\transports\grpc.py:79, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)
#      76         },
#      77     )
# ---> 79 response = continuation(client_call_details, request)
#      80 if logging_enabled:  # pragma: NO COVER
#      81     response_metadata = response.trailing_metadata()
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\grpc\_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\grpc\_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)
#    1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File e:\PwC_Pocs\GenAI\Project_1\.venv_11\Lib\site-packages\grpc\_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
result
# Out:
# {'question': 'What is the total revenue per year?',
#  'next_action': 'END',
#  'cypher_errors': [],
#  'database_records': [{'year': '2016', 'revenue': 2427378.527599994},
#   {'year': '2017', 'revenue': 3447208.242499996},
#   {'year': '2018', 'revenue': 1814529.7874999954}],
#  'steps': ['generate_cypher',
#   'validate_cypher',
#   'execute_cypher',
#   'generate_final_answer'],
#  'answer': 'The total revenue per year is:\n*   **2016**: $2,427,378.53\n*   **2017**: $3,447,208.24\n*   **2018**: $1,814,529.79',
#  'cypher_statement': 'MATCH (order:Order)-[ci:CONTAINS_ITEM]->(product:Product)\nWITH toString(date(order.order_date).year) AS year, SUM((ci.list_price * ci.quantity) * (1 - ci.discount)) AS revenue\nRETURN year, revenue\nORDER BY year'}
